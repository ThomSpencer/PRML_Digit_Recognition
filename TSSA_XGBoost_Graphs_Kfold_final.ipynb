# %%
# ===============================
# IMPORTS
# ===============================
import pandas as pd
import matplotlib.pyplot as plt
import timeit
from collections import Counter
import csv
import string

import xgboost as xgb
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize

import cv2
import numpy as np
import os
import imutils
from imutils.contours import sort_contours

from sklearn.model_selection import KFold,RandomizedSearchCV
import seaborn as sns

# %%
# ===============================
# SETTINGS
# ===============================
from pandas import DataFrame


img_size = 32
max_train = 50000000
max_val = 5000000

max_images = (max_train + max_val)

train_dir = "dataset/train_v2/train"
test_dir = "dataset/test_v2/test"
val_dir   = "dataset/validation_v2/validation"

train_csv_path = "dataset/written_name_train_v2.csv"
test_csv_path = "dataset/written_name_test_v2.csv"
val_csv_path   = "dataset/written_name_validation_v2.csv"

# ===============================
# LOAD CSV LABELS
# ===============================
train_csv: DataFrame = pd.read_csv(train_csv_path)
test_csv: DataFrame = pd.read_csv(test_csv_path)
val_csv: DataFrame   = pd.read_csv(val_csv_path)

# Ensure labels are strings
train_csv["IDENTITY"] = train_csv["IDENTITY"].astype(str)
test_csv["IDENTITY"] = test_csv["IDENTITY"].astype(str)
val_csv["IDENTITY"]   = val_csv["IDENTITY"].astype(str)

train_file_to_label = dict(zip(train_csv['FILENAME'], train_csv['IDENTITY']))
test_file_to_label = dict(zip(test_csv['FILENAME'], test_csv['IDENTITY']))
val_file_to_label   = dict(zip(val_csv['FILENAME'], val_csv['IDENTITY']))

# %%
# ===============================
# DATASET EXPLORATION
# ===============================
print("\nTrain CSV\n",train_csv.head())
print("\nTest CSV\n",test_csv.head())
print("\nValidation CSV\n",val_csv.head())

# Counter for letters
letter_counts = Counter()

with open(train_csv_path, newline="", encoding="utf-8") as f:
    reader = csv.reader(f)
    for row in reader:
        # Join all columns into one string
        text = " ".join(row).lower()

        # Keep only alphabet letters
        for ch in text:
            if ch in string.ascii_lowercase:
                letter_counts[ch] += 1

# Print results sorted alphabetically
for letter in string.ascii_lowercase:
    print(f"{letter}: {letter_counts[letter]}")
# Out:
# Train CSV
#            FILENAME   IDENTITY
# 0  TRAIN_00001.jpg  BALTHAZAR
# 1  TRAIN_00002.jpg      SIMON
# 2  TRAIN_00003.jpg      BENES
# 3  TRAIN_00004.jpg    LA LOVE
# 4  TRAIN_00005.jpg     DAPHNE
#
# Test CSV
#          FILENAME  IDENTITY
# 0  TEST_0001.jpg     KEVIN
# 1  TEST_0002.jpg  CLOTAIRE
# 2  TEST_0003.jpg      LENA
# 3  TEST_0004.jpg     JULES
# 4  TEST_0005.jpg   CHERPIN
#
# Validation CSV
#                FILENAME    IDENTITY
# 0  VALIDATION_0001.jpg       BILEL
# 1  VALIDATION_0002.jpg  LAUMIONIER
# 2  VALIDATION_0003.jpg         LEA
# 3  VALIDATION_0004.jpg   JEAN-ROCH
# 4  VALIDATION_0005.jpg        RUPP
# a: 600618
# b: 45966
# c: 68144
# d: 60504
# e: 270852
# f: 18288
# g: 370096
# h: 61724
# i: 504863
# j: 346765
# k: 14082
# l: 161202
# m: 83719
# n: 498167
# o: 136385
# p: 360564
# q: 5166
# r: 479325
# s: 91419
# t: 432511
# u: 96417
# v: 25094
# w: 5505
# x: 11342
# y: 30831
# z: 14177

# %%
letters = sorted(letter_counts.keys())
counts = [letter_counts[letter] for letter in letters]

# Plot histogram
plt.figure(figsize=(8,5))
plt.bar(letters, counts, color='skyblue')
plt.xlabel('Letters')
plt.ylabel('Counts')
plt.title('Letter Frequency Histogram')
plt.show()

# %%
# ===============================
# MANUAL LETTER SPLITTER
# ===============================

def get_bounding_boxes(img_path: str, show_plts = False):
    if not os.path.exists(img_path):
        print("❌ Error: File not found at", img_path)
        return [], None

    image = cv2.imread(img_path)
    if image is None:
        print("❌ Error: Could not read the image. Check file format or path.")
        return [], None
    
    if show_plts:
        print("✅ Loaded image shape:", image.shape)


        plt.figure(figsize=(8,6))
        plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        plt.axis('off')
        plt.title("Original Image")
        plt.show()

    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Threshold + dilation
    # Flip image to be black on white instead of white on black 
    # Fill holes in contours
    _, thresh1 = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY_INV)
    dilated = cv2.dilate(thresh1, kernel=filter_kernel, iterations=2)

    if show_plts:
        plt.figure(figsize=(8,6))
        plt.imshow(cv2.cvtColor(dilated, cv2.COLOR_BGR2RGB))
        plt.axis('off')
        plt.title("Dilated Image")
        plt.show()

    # Find contours
    cnts = cv2.findContours(dilated.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)

    if len(cnts) == 0:
        if show_plts:
            print("Detected 0 letters: ", img_path)
        return image, []

    cnts = sort_contours(cnts, method="left-to-right")[0]

    letters = []

    for i, c in enumerate(cnts):
        if cv2.contourArea(c) < 10:
            continue
        x, y, w, h = cv2.boundingRect(c)

        # add buffer area
        w += 2
        h += 2

        x -= 1
        y -= 1

        # Extract ROI
        roi = gray[y:y+h, x:x+w]

        # Safety check
        if roi.size == 0 or roi.shape[0] == 0 or roi.shape[1] == 0:
            if show_plts:
                print(f"⚠️ Skipping empty ROI at contour {i} -> x={x}, y={y}, w={w}, h={h}")
            continue
        if show_plts:
            print(f"➡️ Contour {i}: ROI shape = {roi.shape}")

        # Draw bounding box
        cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)

        # Preprocess ROI for CNN
        thresh = cv2.threshold(roi, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)[1]
        thresh = cv2.resize(thresh, (img_size, img_size), interpolation=cv2.INTER_CUBIC)
        thresh = thresh.astype("float32") / 255.0
        # thresh = np.expand_dims(thresh, axis=-1)  # (32, 32, 1)
        # thresh = np.expand_dims(thresh, axis=0)   # (1, 32, 32, 1)
        # thresh = np.squeeze(thresh)               # ()

        letters.append(thresh)
    return image, letters

def plot_processed_images(images, img_size=32):
    """
    Plots a list of preprocessed images as subplots.

    Parameters:
        images: list or array of preprocessed images, shape can be (N, H, W, 1) or (N, H, W)
        img_size: size of the images (for reshaping if needed)
    """
    # Ensure images are 2D for plotting
    processed_images = []
    for im in images:
        if im.ndim == 4:  # (1, H, W, 1)
            processed_images.append(im[0, :, :, 0])
        elif im.ndim == 3 and im.shape[-1] == 1:  # (H, W, 1)
            processed_images.append(im[:, :, 0])
        else:
            processed_images.append(im)

    n = len(processed_images)
    cols = 6
    rows = (n // cols) + int(n % cols != 0)

    plt.figure(figsize=(3*cols, 3*rows))
    for i, roi in enumerate(processed_images):
        plt.subplot(rows, cols, i+1)
        plt.imshow(roi, cmap='gray')
        plt.axis('off')
    plt.suptitle("Preprocessed Images", fontsize=16)
    plt.tight_layout()
    plt.show()  

filter_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (2,2))

example_image = os.path.join(r"dataset\test_v2\test", "TEST_0003.jpg")
image, counturs = get_bounding_boxes(example_image, show_plts=True)

plt.figure(figsize=(8,6))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB)) # type: ignore
plt.axis('off')
plt.title("Letter bounding boxes")
plt.show()

plot_processed_images(images=counturs)
# Out:
# ✅ Loaded image shape: (44, 324, 3)
# ➡️ Contour 0: ROI shape = (18, 12)
# ➡️ Contour 1: ROI shape = (23, 14)
# ➡️ Contour 2: ROI shape = (18, 12)
# ➡️ Contour 3: ROI shape = (18, 13)

# %%
# ===============================
# BENCHMARK
# ===============================

example_image = os.path.join(r"dataset\test_v2\test", "TEST_0001.jpg")

def wrapper():
    get_bounding_boxes(example_image)
time = timeit.timeit(wrapper, number=50)
print("Time to run: ",time)
print("Time for all images: ",time * (max_train + max_val))
# Out:
# Time to run:  0.036522400012472644
# Time for all images:  2008732.0006859954

# %%
# ===============================
# LOGISTIC REGRESSION PREP
# ===============================
def logistic_image_prep(file_name,folder_path,file_label, debug=False):
    example_image = os.path.join(folder_path, file_name)
    image, counturs = get_bounding_boxes(example_image, show_plts=debug)

    if debug:
        plt.figure(figsize=(8,6))
        plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB)) # type: ignore
        plt.axis('off')
        plt.show()

        plot_processed_images(images=counturs)

    if debug:
        print(train_file_to_label[file_name])

    if len(file_label) != len(counturs): # type: ignore
        if debug:
            print("Mismatch in counturs and label")
        return 1
    return [[img, label] for img, label in zip(counturs, file_label)]  # type: ignore 
            # (letter[], letterLabel)

# %%
# ===============================
# CREATE TRAINING SET
# ===============================
print("Creating Training Sets")
errors = 0
images = []
for idx, file in train_csv.iterrows():
    file_label = file["IDENTITY"]
    file_name = file["FILENAME"]
    res = logistic_image_prep(file_name=file_name,folder_path=r"dataset\train_v2\train",file_label=file_label)
    if res != 1:
        images.extend(res)
    else:
        errors += 1

    if len(images) >= max_train:
        print("Rows Processed: ", idx)
        print("% of full dataset: ", round(idx / len(train_csv)*100,2)) # type: ignore
        break

print("Errors: ", errors)
print("Images:",len(images))

arr = np.array(images, dtype=object)   # shape (3, 2)


# Split into two arrays (columns)
x_train = np.stack(arr[:, 0], axis=0)    # type: ignore
y_train = arr[:, 1]   # second column

print(x_train.shape)
# Out:
# Creating Training Sets
# Errors:  182922
# Images: 942023
# (942023, 32, 32)

# %%
# ===============================
# CREATE VALIDATION SET
# ===============================
print("Creating validation Sets")
errors = 0
images = []
for idx, file in val_csv.iterrows():
    file_label = file["IDENTITY"]
    file_name = file["FILENAME"]
    res = logistic_image_prep(file_name=file_name,folder_path=r"dataset\validation_v2\validation",file_label=file_label)
    if res != 1:
        images.extend(res)
    else:
        errors += 1

    if len(images) >= max_val:
        print("Rows Processed: ", idx)
        print("% of full dataset: ", round(idx / len(test_csv)*100,2)) # type: ignore
        break

print("Errors: ", errors)
print("Images:",len(images))

arr = np.array(images, dtype=object)   # shape (3, 2)

# Split into two arrays (columns)
x_val = np.stack(arr[:, 0], axis=0) # type: ignore
y_val = arr[:, 1]   # second column

print(x_val.shape)
# Out:
# Creating validation Sets
# Errors:  22608
# Images: 119472
# (942023, 32, 32)

# %%
# Flatten each 28x28 image into a 784-length vector
x_train_flat = x_train.reshape(x_train.shape[0], -1)
x_val_flat = x_val.reshape(x_val.shape[0], -1)

# Normalize pixel values to range [0, 1]
x_train_flat = x_train_flat.astype('float32') / 255.0
x_val_flat = x_val_flat.astype('float32') / 255.0

# %%
def fit_and_score(estimator, X_train, X_test, y_train, y_test):
    """Fit the estimator on the train set and score it on both sets"""
    estimator.fit(X_train, y_train, 
                  eval_set=[(X_train, y_train), (X_test, y_test)])

    evals_result = estimator.evals_result()
    train_score = estimator.score(X_train, y_train)
    test_score = estimator.score(X_test, y_test)

    return estimator, train_score, test_score, evals_result 


from sklearn.preprocessing import LabelEncoder

# Initialize encoder
le = LabelEncoder()

# Fit on all possible labels (train + test so encoding is consistent)
all_labels = list(y_train) + list(y_val)
le.fit(all_labels)

# Transform to integers
y_train_enc = le.transform(y_train)
y_val_enc  = le.transform(y_val)


results = {}
# Best hyperparams found using cross and randomsearch
xgb_model = xgb.XGBClassifier(early_stopping_rounds=3, 
                        eval_metric=["mlogloss", "merror"],
                        tree_method="hist",
                        device="cuda",
                        subsample=0.9,
                        n_estimators=100,
                        max_depth=7,
                        learning_rate=0.2)

# %%
est, train_score, test_score, evals_result = fit_and_score(xgb_model, x_train_flat, x_val_flat, y_train_enc, y_val_enc)
# Out:
# [0]	validation_0-mlogloss:1.69216	validation_0-merror:0.20387	validation_1-mlogloss:1.69703	validation_1-merror:0.20677
# [1]	validation_0-mlogloss:1.45500	validation_0-merror:0.18230	validation_1-mlogloss:1.46330	validation_1-merror:0.18614
# [2]	validation_0-mlogloss:1.28476	validation_0-merror:0.17085	validation_1-mlogloss:1.29657	validation_1-merror:0.17541
# [3]	validation_0-mlogloss:1.15165	validation_0-merror:0.16233	validation_1-mlogloss:1.16663	validation_1-merror:0.16770
# [4]	validation_0-mlogloss:1.04413	validation_0-merror:0.15559	validation_1-mlogloss:1.06192	validation_1-merror:0.16131
# [5]	validation_0-mlogloss:0.95662	validation_0-merror:0.15026	validation_1-mlogloss:0.97676	validation_1-merror:0.15638
# [6]	validation_0-mlogloss:0.88406	validation_0-merror:0.14567	validation_1-mlogloss:0.90660	validation_1-merror:0.15236
# [7]	validation_0-mlogloss:0.82197	validation_0-merror:0.14114	validation_1-mlogloss:0.84675	validation_1-merror:0.14851
# [8]	validation_0-mlogloss:0.76975	validation_0-merror:0.13735	validation_1-mlogloss:0.79682	validation_1-merror:0.14506
# [9]	validation_0-mlogloss:0.72434	validation_0-merror:0.13345	validation_1-mlogloss:0.75360	validation_1-merror:0.14221
# [10]	validation_0-mlogloss:0.68613	validation_0-merror:0.13012	validation_1-mlogloss:0.71735	validation_1-merror:0.13917
# [11]	validation_0-mlogloss:0.65276	validation_0-merror:0.12700	validation_1-mlogloss:0.68602	validation_1-merror:0.13639
# [12]	validation_0-mlogloss:0.62398	validation_0-merror:0.12423	validation_1-mlogloss:0.65941	validation_1-merror:0.13366
# [13]	validation_0-mlogloss:0.59873	validation_0-merror:0.12164	validation_1-mlogloss:0.63614	validation_1-merror:0.13150
# [14]	validation_0-mlogloss:0.57610	validation_0-merror:0.11908	validation_1-mlogloss:0.61563	validation_1-merror:0.12936
# [15]	validation_0-mlogloss:0.55667	validation_0-merror:0.11670	validation_1-mlogloss:0.59820	validation_1-merror:0.12739
# [16]	validation_0-mlogloss:0.53931	validation_0-merror:0.11456	validation_1-mlogloss:0.58292	validation_1-merror:0.12564
# [17]	validation_0-mlogloss:0.52356	validation_0-merror:0.11251	validation_1-mlogloss:0.56919	validation_1-merror:0.12417
# [18]	validation_0-mlogloss:0.50930	validation_0-merror:0.11044	validation_1-mlogloss:0.55701	validation_1-merror:0.12242
# [19]	validation_0-mlogloss:0.49637	validation_0-merror:0.10850	validation_1-mlogloss:0.54602	validation_1-merror:0.12089
# [20]	validation_0-mlogloss:0.48445	validation_0-merror:0.10665	validation_1-mlogloss:0.53618	validation_1-merror:0.11934
# [21]	validation_0-mlogloss:0.47376	validation_0-merror:0.10490	validation_1-mlogloss:0.52764	validation_1-merror:0.11804
# [22]	validation_0-mlogloss:0.46383	validation_0-merror:0.10326	validation_1-mlogloss:0.51991	validation_1-merror:0.11671
# [23]	validation_0-mlogloss:0.45489	validation_0-merror:0.10170	validation_1-mlogloss:0.51306	validation_1-merror:0.11542
# [24]	validation_0-mlogloss:0.44630	validation_0-merror:0.10005	validation_1-mlogloss:0.50646	validation_1-merror:0.11421
# [25]	validation_0-mlogloss:0.43863	validation_0-merror:0.09862	validation_1-mlogloss:0.50086	validation_1-merror:0.11311
# [26]	validation_0-mlogloss:0.43107	validation_0-merror:0.09712	validation_1-mlogloss:0.49547	validation_1-merror:0.11219
# [27]	validation_0-mlogloss:0.42390	validation_0-merror:0.09560	validation_1-mlogloss:0.49044	validation_1-merror:0.11098
# [28]	validation_0-mlogloss:0.41738	validation_0-merror:0.09431	validation_1-mlogloss:0.48608	validation_1-merror:0.11027
# [29]	validation_0-mlogloss:0.41099	validation_0-merror:0.09293	validation_1-mlogloss:0.48189	validation_1-merror:0.10945
# [30]	validation_0-mlogloss:0.40480	validation_0-merror:0.09167	validation_1-mlogloss:0.47780	validation_1-merror:0.10836
# [31]	validation_0-mlogloss:0.39907	validation_0-merror:0.09051	validation_1-mlogloss:0.47415	validation_1-merror:0.10776
# [32]	validation_0-mlogloss:0.39362	validation_0-merror:0.08930	validation_1-mlogloss:0.47080	validation_1-merror:0.10689
# [33]	validation_0-mlogloss:0.38829	validation_0-merror:0.08812	validation_1-mlogloss:0.46774	validation_1-merror:0.10628
# [34]	validation_0-mlogloss:0.38332	validation_0-merror:0.08706	validation_1-mlogloss:0.46486	validation_1-merror:0.10551
# [35]	validation_0-mlogloss:0.37821	validation_0-merror:0.08579	validation_1-mlogloss:0.46195	validation_1-merror:0.10503
# [36]	validation_0-mlogloss:0.37336	validation_0-merror:0.08460	validation_1-mlogloss:0.45930	validation_1-merror:0.10428
# [37]	validation_0-mlogloss:0.36916	validation_0-merror:0.08362	validation_1-mlogloss:0.45703	validation_1-merror:0.10380
# [38]	validation_0-mlogloss:0.36499	validation_0-merror:0.08273	validation_1-mlogloss:0.45483	validation_1-merror:0.10320
# [39]	validation_0-mlogloss:0.36083	validation_0-merror:0.08179	validation_1-mlogloss:0.45274	validation_1-merror:0.10254
# [40]	validation_0-mlogloss:0.35679	validation_0-merror:0.08083	validation_1-mlogloss:0.45070	validation_1-merror:0.10211
# [41]	validation_0-mlogloss:0.35300	validation_0-merror:0.08000	validation_1-mlogloss:0.44895	validation_1-merror:0.10150
# [42]	validation_0-mlogloss:0.34940	validation_0-merror:0.07919	validation_1-mlogloss:0.44735	validation_1-merror:0.10104
# [43]	validation_0-mlogloss:0.34571	validation_0-merror:0.07831	validation_1-mlogloss:0.44563	validation_1-merror:0.10053
# [44]	validation_0-mlogloss:0.34209	validation_0-merror:0.07750	validation_1-mlogloss:0.44400	validation_1-merror:0.10012
# [45]	validation_0-mlogloss:0.33891	validation_0-merror:0.07671	validation_1-mlogloss:0.44240	validation_1-merror:0.09962
# [46]	validation_0-mlogloss:0.33565	validation_0-merror:0.07592	validation_1-mlogloss:0.44108	validation_1-merror:0.09910
# [47]	validation_0-mlogloss:0.33242	validation_0-merror:0.07526	validation_1-mlogloss:0.43956	validation_1-merror:0.09877
# [48]	validation_0-mlogloss:0.32920	validation_0-merror:0.07452	validation_1-mlogloss:0.43842	validation_1-merror:0.09870
# [49]	validation_0-mlogloss:0.32612	validation_0-merror:0.07385	validation_1-mlogloss:0.43720	validation_1-merror:0.09846
# [50]	validation_0-mlogloss:0.32292	validation_0-merror:0.07303	validation_1-mlogloss:0.43594	validation_1-merror:0.09798
# [51]	validation_0-mlogloss:0.32014	validation_0-merror:0.07241	validation_1-mlogloss:0.43494	validation_1-merror:0.09763
# [52]	validation_0-mlogloss:0.31715	validation_0-merror:0.07176	validation_1-mlogloss:0.43383	validation_1-merror:0.09739
# [53]	validation_0-mlogloss:0.31439	validation_0-merror:0.07112	validation_1-mlogloss:0.43280	validation_1-merror:0.09707
# [54]	validation_0-mlogloss:0.31187	validation_0-merror:0.07052	validation_1-mlogloss:0.43191	validation_1-merror:0.09696
# [55]	validation_0-mlogloss:0.30875	validation_0-merror:0.06988	validation_1-mlogloss:0.43085	validation_1-merror:0.09656
# [56]	validation_0-mlogloss:0.30625	validation_0-merror:0.06926	validation_1-mlogloss:0.43002	validation_1-merror:0.09641
# [57]	validation_0-mlogloss:0.30369	validation_0-merror:0.06871	validation_1-mlogloss:0.42922	validation_1-merror:0.09605
# [58]	validation_0-mlogloss:0.30124	validation_0-merror:0.06816	validation_1-mlogloss:0.42851	validation_1-merror:0.09578
# [59]	validation_0-mlogloss:0.29880	validation_0-merror:0.06760	validation_1-mlogloss:0.42768	validation_1-merror:0.09566
# [60]	validation_0-mlogloss:0.29643	validation_0-merror:0.06705	validation_1-mlogloss:0.42701	validation_1-merror:0.09544
# [61]	validation_0-mlogloss:0.29392	validation_0-merror:0.06649	validation_1-mlogloss:0.42612	validation_1-merror:0.09526
# [62]	validation_0-mlogloss:0.29159	validation_0-merror:0.06598	validation_1-mlogloss:0.42550	validation_1-merror:0.09510
# [63]	validation_0-mlogloss:0.28938	validation_0-merror:0.06551	validation_1-mlogloss:0.42495	validation_1-merror:0.09488
# [64]	validation_0-mlogloss:0.28725	validation_0-merror:0.06508	validation_1-mlogloss:0.42446	validation_1-merror:0.09468
# [65]	validation_0-mlogloss:0.28499	validation_0-merror:0.06455	validation_1-mlogloss:0.42382	validation_1-merror:0.09463
# [66]	validation_0-mlogloss:0.28287	validation_0-merror:0.06410	validation_1-mlogloss:0.42329	validation_1-merror:0.09442
# [67]	validation_0-mlogloss:0.28054	validation_0-merror:0.06358	validation_1-mlogloss:0.42262	validation_1-merror:0.09406
# [68]	validation_0-mlogloss:0.27851	validation_0-merror:0.06313	validation_1-mlogloss:0.42207	validation_1-merror:0.09395
# [69]	validation_0-mlogloss:0.27642	validation_0-merror:0.06263	validation_1-mlogloss:0.42159	validation_1-merror:0.09393
# [70]	validation_0-mlogloss:0.27444	validation_0-merror:0.06213	validation_1-mlogloss:0.42110	validation_1-merror:0.09375
# [71]	validation_0-mlogloss:0.27235	validation_0-merror:0.06175	validation_1-mlogloss:0.42052	validation_1-merror:0.09353
# [72]	validation_0-mlogloss:0.27014	validation_0-merror:0.06127	validation_1-mlogloss:0.41990	validation_1-merror:0.09333
# [73]	validation_0-mlogloss:0.26824	validation_0-merror:0.06086	validation_1-mlogloss:0.41953	validation_1-merror:0.09338
# [74]	validation_0-mlogloss:0.26640	validation_0-merror:0.06046	validation_1-mlogloss:0.41909	validation_1-merror:0.09322
# [75]	validation_0-mlogloss:0.26443	validation_0-merror:0.06004	validation_1-mlogloss:0.41875	validation_1-merror:0.09318
# [76]	validation_0-mlogloss:0.26239	validation_0-merror:0.05963	validation_1-mlogloss:0.41827	validation_1-merror:0.09300
# [77]	validation_0-mlogloss:0.26040	validation_0-merror:0.05919	validation_1-mlogloss:0.41784	validation_1-merror:0.09291
# [78]	validation_0-mlogloss:0.25841	validation_0-merror:0.05882	validation_1-mlogloss:0.41742	validation_1-merror:0.09267
# [79]	validation_0-mlogloss:0.25664	validation_0-merror:0.05842	validation_1-mlogloss:0.41695	validation_1-merror:0.09242
# [80]	validation_0-mlogloss:0.25462	validation_0-merror:0.05800	validation_1-mlogloss:0.41650	validation_1-merror:0.09231
# [81]	validation_0-mlogloss:0.25283	validation_0-merror:0.05764	validation_1-mlogloss:0.41613	validation_1-merror:0.09198
# [82]	validation_0-mlogloss:0.25100	validation_0-merror:0.05721	validation_1-mlogloss:0.41584	validation_1-merror:0.09193
# [83]	validation_0-mlogloss:0.24939	validation_0-merror:0.05684	validation_1-mlogloss:0.41561	validation_1-merror:0.09185
# [84]	validation_0-mlogloss:0.24763	validation_0-merror:0.05651	validation_1-mlogloss:0.41529	validation_1-merror:0.09170
# [85]	validation_0-mlogloss:0.24580	validation_0-merror:0.05614	validation_1-mlogloss:0.41496	validation_1-merror:0.09163
# [86]	validation_0-mlogloss:0.24403	validation_0-merror:0.05581	validation_1-mlogloss:0.41463	validation_1-merror:0.09139
# [87]	validation_0-mlogloss:0.24236	validation_0-merror:0.05553	validation_1-mlogloss:0.41438	validation_1-merror:0.09136
# [88]	validation_0-mlogloss:0.24063	validation_0-merror:0.05516	validation_1-mlogloss:0.41410	validation_1-merror:0.09123
# [89]	validation_0-mlogloss:0.23887	validation_0-merror:0.05478	validation_1-mlogloss:0.41367	validation_1-merror:0.09100
# [90]	validation_0-mlogloss:0.23734	validation_0-merror:0.05443	validation_1-mlogloss:0.41353	validation_1-merror:0.09088
# [91]	validation_0-mlogloss:0.23579	validation_0-merror:0.05412	validation_1-mlogloss:0.41335	validation_1-merror:0.09071
# [92]	validation_0-mlogloss:0.23419	validation_0-merror:0.05384	validation_1-mlogloss:0.41318	validation_1-merror:0.09064
# [93]	validation_0-mlogloss:0.23259	validation_0-merror:0.05350	validation_1-mlogloss:0.41290	validation_1-merror:0.09060
# [94]	validation_0-mlogloss:0.23104	validation_0-merror:0.05320	validation_1-mlogloss:0.41273	validation_1-merror:0.09056
# [95]	validation_0-mlogloss:0.22936	validation_0-merror:0.05286	validation_1-mlogloss:0.41250	validation_1-merror:0.09041
# [96]	validation_0-mlogloss:0.22766	validation_0-merror:0.05251	validation_1-mlogloss:0.41229	validation_1-merror:0.09033
# [97]	validation_0-mlogloss:0.22606	validation_0-merror:0.05218	validation_1-mlogloss:0.41202	validation_1-merror:0.09015
# [98]	validation_0-mlogloss:0.22446	validation_0-merror:0.05187	validation_1-mlogloss:0.41183	validation_1-merror:0.09010
# [99]	validation_0-mlogloss:0.22299	validation_0-merror:0.05157	validation_1-mlogloss:0.41167	validation_1-merror:0.08996

# %%
xgb_model: xgb.XGBClassifier = est
#import joblib
#xgb_model = joblib.load("XGBoostFinal.pkl") # type: ignore

# Accuracy
train_acc = xgb_model.score(x_train_flat, y_train_enc)
val_acc = xgb_model.score(x_val_flat, y_val_enc)

print(f"Training Accuracy: {train_acc}")
print(f"Validation Accuracy: {val_acc}")

# Eval metrics per iteration
evals_result = xgb_model.evals_result()
# Out:
# Training Accuracy: 0.9484333185070852
# Validation Accuracy: 0.9100374983259676

# %%
# --- Plot logloss ---
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(evals_result['validation_0']['mlogloss'], label='Train Logloss')
plt.plot(evals_result['validation_1']['mlogloss'], label='Val Logloss')
plt.xlabel('Iteration')
plt.ylabel('Log Loss')
plt.title('Training vs Validation Log Loss')
plt.legend()
plt.grid(True)

# --- Plot classification error ---
plt.subplot(1, 2, 2)
plt.plot(evals_result['validation_0']['merror'], label='Train Error')
plt.plot(evals_result['validation_1']['merror'], label='Val Error')
plt.xlabel('Iteration')
plt.ylabel('Error Rate')
plt.title('Training vs Validation Error')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
y_pred = xgb_model.predict(x_val_flat)
cm = confusion_matrix(y_val_enc, y_pred)
print("\nClassification Report:\n", classification_report(y_val_enc, y_pred,target_names=le.classes_[0:-1]))

class_names = le.classes_[0:-1]

# Normalize confusion matrix to percentages for coloring
cm_percent = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Create DataFrame for seaborn heatmap
cm_percent_df = pd.DataFrame(cm_percent, index=class_names, columns=class_names)

# Plot heatmap
plt.figure(figsize=(16,15))
sns.heatmap(
    cm_percent_df,
    annot=cm,                # annotate with raw counts
    fmt='d',                 # integer format
    cmap='coolwarm',
    cbar=True
)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix (colors = % of row, labels = counts)')
plt.show()
# Out:
# c:\Users\thomw\LaptopBackup\UNI\PRML\PRML_Digit_Recognition\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\thomw\LaptopBackup\UNI\PRML\PRML_Digit_Recognition\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\thomw\LaptopBackup\UNI\PRML\PRML_Digit_Recognition\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Classification Report:
#                precision    recall  f1-score   support
#
#                    0.00      0.00      0.00       297
#            '       0.00      0.00      0.00         9
#            -       0.70      0.80      0.74       293
#            A       0.90      0.95      0.92     15638
#            B       0.89      0.85      0.87      2423
#            C       0.90      0.90      0.90      3823
#            D       0.86      0.86      0.86      3270
#            E       0.93      0.94      0.94     15018
#            F       0.90      0.83      0.86      1004
#            G       0.93      0.88      0.91      2106
#            H       0.85      0.85      0.85      3462
#            I       0.91      0.93      0.92      9324
#            J       0.87      0.82      0.85       874
#            K       0.88      0.82      0.85       792
#            L       0.92      0.93      0.93      9158
#            M       0.86      0.86      0.86      4745
#            N       0.93      0.93      0.93      9325
#            O       0.91      0.91      0.91      7521
#            P       0.89      0.88      0.88      1514
#            Q       0.89      0.65      0.75       247
#            R       0.93      0.91      0.92      8094
#            S       0.94      0.94      0.94      4925
#            T       0.94      0.93      0.93      5392
#            U       0.90      0.92      0.91      5296
#            V       0.89      0.84      0.86      1380
#            W       0.90      0.69      0.78       303
#            X       0.94      0.83      0.88       696
#            Y       0.91      0.90      0.91      1748
#            Z       0.95      0.85      0.90       786
#            `       0.00      0.00      0.00         3
#            a       0.00      0.00      0.00         6
#
#     accuracy                           0.91    119472
#    macro avg       0.78      0.75      0.77    119472
# weighted avg       0.91      0.91      0.91    119472

# %%
y_pred_proba = xgb_model.predict_proba(x_val_flat)

# Get list of classes from the label encoder
classes = le.classes_

# Binarize the labels (one-hot encode)
y_val_bin = label_binarize(y_val_enc, classes=np.arange(len(classes)))
n_classes = y_val_bin.shape[1]

fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_val_bin[:, i], y_pred_proba[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Micro-average (considers all classes at once)
fpr["micro"], tpr["micro"], _ = roc_curve(y_val_bin.ravel(), y_pred_proba.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Macro-average (average of all class AUCs)
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

plt.figure(figsize=(8, 6))
for i, label in enumerate(classes):
    plt.plot(fpr[i], tpr[i], lw=1.5, label=f'Class {label} (AUC = {roc_auc[i]:.3f})')
plt.plot([0, 1], [0, 1], 'k--', label='Chance')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves per Class')
plt.legend(loc='lower right', fontsize='small')
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 6))
plt.plot(fpr["micro"], tpr["micro"],
         label=f'Micro-average (AUC = {roc_auc["micro"]:.3f})',
         color='deeppink', linestyle='-', linewidth=2)
plt.plot(fpr["macro"], tpr["macro"],
         label=f'Macro-average (AUC = {roc_auc["macro"]:.3f})',
         color='navy', linestyle='--', linewidth=2)
plt.plot([0, 1], [0, 1], 'k--', label='Chance')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Micro vs Macro ROC Curves')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
# Out:
# c:\Users\thomw\LaptopBackup\UNI\PRML\PRML_Digit_Recognition\.venv\Lib\site-packages\sklearn\metrics\_ranking.py:1201: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(

# %%
y_pred_decoded = le.inverse_transform(y_pred)

correct_indices = np.where(y_pred_decoded == y_val)[0]
incorrect_indices = np.where(y_pred_decoded != y_val)[0]

# Visualize first 10 correct and incorrect predictions
plt.figure(figsize=(12, 3.5))

# First row: correct predictions
for i, idx in enumerate(correct_indices[:10]):
    plt.subplot(2, 10, i+1)
    plt.imshow(x_val[idx], cmap='gray')
    plt.title(f"P:{y_pred_decoded[idx]}\nT:{y_val[idx]}", color='green', fontsize=8)
    plt.axis('off')

# Second row: incorrect predictions
for i, idx in enumerate(incorrect_indices[:10]):
    plt.subplot(2, 10, 10 + i + 1)
    plt.imshow(x_val[idx], cmap='gray')
    plt.title(f"P:{y_pred_decoded[idx]}\nT:{y_val[idx]}", color='red', fontsize=8)
    plt.axis('off')

plt.suptitle("Top Row: Correct Predictions | Bottom Row: Incorrect Predictions", fontsize=14)
plt.show()

# %%
import joblib
joblib.dump(xgb_model, "XGBoostFinal.pkl")
#joblib save us
# Out:
# ['XGBoostFinal.pkl']
